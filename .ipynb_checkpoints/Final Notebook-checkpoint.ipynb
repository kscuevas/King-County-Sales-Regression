# %% [markdown]
# * Student name: Michael Cuevas
# * Student pace: self paced / part time / full time: Flex (Self Paced)
# * Scheduled project review date/time:
# * Instructor name: Morgan Jones
# * Blog post URL:
#
#
# # King County Sales Regression Project (Phase 2 Project)
# ![image.png](attachment:image.png)
#
# # Business Understanding
# *EXIT EAST Realty is a real estate agency located in Texas and is looking in to expanding their business and services into the King County area of Washington. I have reached out and spoken with them in regards to which aspects of interest they'd like me to look into and investigate so that they can be successful in the region upon opening for business. I intend to do this by analyzing recent sales for housing in the area as well as recommending which type of housing locations to invest in such as housing distance in correlation to cities, the type of living situation the house is made for (such as for a single family, or one person) and whether the home is considered a common or luxury home so that they can better enter the market in this area.*
#
# This analysis will be specifically be going through the following points of interest:
# * Housing prices in correlation to distance to cities.
# * Specific living accomidations that directly affect housing pricing depending who the housing in question is made for.
# * Categorizing housing pricing based on parameters that make them common or luxury homes.

# %% [markdown]
# # Importing Data & Analysis Selection Rationale
#
# This project will be utilizing information sourced from `kc_house_data.csv` from within our data file attatched to this notebook.
